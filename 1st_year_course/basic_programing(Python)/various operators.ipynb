# %% [markdown]
# > 📘 학습 출처
# 패스트캠퍼스 『한 번에 끝내는 컴퓨터 공학 전공필수 & 인공지능 심화 초격차 패키지 Online.』
#
# > ⚖️ 저작권 안내
# 본 노트북의 코드는 개인 학습 목적을 위해 직접 작성된 것입니다.
# 강의에서 제공된 원본 코드(있을 경우)의 저작권은 패스트캠퍼스 및 해당 강사에게 있습니다.
# 강의 영상·슬라이드·원본 자료는 포함되지 않습니다.

# %%
# 기초 연산자 - Boolean

a, b = 4, 5
print(a == b)
print(1 + 3 == 2 + 2)
# Out:
# False
# True

# %%
print('a' in 'Happy')
print('b' in 'Happy')
Fruits = ['Apple', 'Banana']; print('Orange' in Fruits)
# Out:
# True
# False
# False

# %%
print(3 > 4 and 6 > 5)
print(3 > 4 or 6 > 5)
print(3 > 4 | 6 > 5)
# Out:
# False
# True
# False

# %%
# 비트 연산자

a = 10 # 비트 단위로 1010
print(a<<1) # 비트 단위로 10100으로 변경 됨
print(a<<2) # 비트 단위로 101000으로 변경 됨
print(a>>1) # 비트 단위로 101로 변경 됨
print(a>>2) # 비트 단위로 10으로 변경 됨
# Out:
# 20
# 40
# 5
# 2

# %%
# 식별 연산자

a, b = [1,2,3], [1,2,3]
print('a == b:', a == b)
print('a is b:', a is b)
# Out:
# a == b: True
# a is b: False

# %%
# 할당 연산자
a = 3
a += 1
print(a)

b = 5
b -= 3
print(b)

c = 6
c *= 7
print(c)

d = 12
d /= 2
print(d)

e = 15
e %= 6
print(e)
# Out:
# 4
# 2
# 42
# 6.0
# 3
