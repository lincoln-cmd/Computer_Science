# %% [markdown]
# 📘 학습 출처
# 패스트캠퍼스 『한 번에 끝내는 컴퓨터 공학 전공필수 & 인공지능 심화 초격차 패키지 Online.』
#
# ⚖️ 저작권 안내
# 본 노트북의 코드는 개인 학습 목적을 위해 직접 작성된 것입니다.
# 강의에서 제공된 원본 코드(있을 경우)의 저작권은 패스트캠퍼스 및 해당 강사에게 있습니다.
# 강의 영상·슬라이드·원본 자료는 포함되지 않습니다.

# %%
# 조건문: if 문

a = int(input())

if a < 0:
    print("0보다 작습니다.")
elif 0 < a < 100:
    print("100보다 작습니다.")
else:
    print("0이거나 100이상 입니다.")
# Out:
# 1031
# 0이거나 100이상 입니다.

# %%
# 조건문: for 문

b = []

for i in [5, 4, 3, 2, 1]:
    b.insert(0, i)
    
print(b)
# Out:
# [1, 2, 3, 4, 5]

# %%
# range 함수 사용

c = list()

for i in range(1, 10, 1):
    c.append(i)
    
print(c)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# 조건문: while 문

d = 1

while d:
    d += 1
    if d % 3 == 0:
        print(f'{d}는 3의 배수 입니다. continue를 실행해 다음 반복문으로 넘어갑니다.')
        continue
    elif d % 7 == 0:
        print(f'{d}는 7의 배수 입니다. pass는 아무것도 수행하지 않고 다음 반복문으로 넘어갑니다.')
        pass
    elif d % 11 == 0:
        print(f'{d}는 11의 배수입니다. break를 수행합니다.')
        break
    
        
print(d)
# Out:
# 3는 3의 배수 입니다. continue를 실행해 다음 반복문으로 넘어갑니다.
# 6는 3의 배수 입니다. continue를 실행해 다음 반복문으로 넘어갑니다.
# 7는 7의 배수 입니다. pass는 아무것도 수행하지 않고 다음 반복문으로 넘어갑니다.
# 9는 3의 배수 입니다. continue를 실행해 다음 반복문으로 넘어갑니다.
# 11는 11의 배수입니다. break를 수행합니다.
# 11

# %%
# 조건문: if문과 for문의 조합

a = list(map(int, input().split()))

for i in a:
    if i > 0:
        print("{}는 양수입니다.".format(i))
    elif i == 0:
        print("{}는 0입니다.".format(i))
    else:
        print("{}는 음수입니다.".format(i))
# Out:
# -7 -3 0 1 6
# -7는 음수입니다.
# -3는 음수입니다.
# 0는 0입니다.
# 1는 양수입니다.
# 6는 양수입니다.
