# %%
c = 3 + 4j
print(c)
a1 = 3
a2 = 4
print(a1 + a2)
# Out:
# (3+4j)
# 7

# %%
# 사칙연산
print(3 * 2 - 8 / 4)
print(25 * 6 / 3 + 17)
print(391084 - 27654881/3418)
print(26 - 10 % 6)

print(12 - (5 + 7 + 1))
print(5 * (6 * 3 / 2))
# Out:
# 4.0
# 67.0
# 382993.04593329434
# 22
# -1
# 45.0

# %%
# 부동소수점
print(0.1 + 0.2) # 10의 -15 제곱 이하의 오차
print(0.3 - (0.1 + 0.2))
# Out:
# 0.30000000000000004
# -5.551115123125783e-17

# %%
print(1e7)
# Out:
# 10000000.0
