# %% [markdown]
# > 📘 학습 출처
# 패스트캠퍼스 『한 번에 끝내는 컴퓨터 공학 전공필수 & 인공지능 심화 초격차 패키지 Online.』
#
# > ⚖️ 저작권 안내
# 본 노트북의 코드는 개인 학습 목적을 위해 직접 작성된 것입니다.
# 강의에서 제공된 원본 코드(있을 경우)의 저작권은 패스트캠퍼스 및 해당 강사에게 있습니다.
# 강의 영상·슬라이드·원본 자료는 포함되지 않습니다.

# %%
def func(count):
    if count > 0:
        print(count, 'now')
        func(count - 1)
    print('result: ', count)
    
func(10)
# Out:
# 10 now
# 9 now
# 8 now
# 7 now
# 6 now
# 5 now
# 4 now
# 3 now
# 2 now
# 1 now
# result:  0
# result:  1
# result:  2
# result:  3
# result:  4
# result:  5
# result:  6
# result:  7
# result:  8
# result:  9
# result:  10

# %%
def func(count):
    if count > 0:
        print(count, 'now')
        print('result: ', count)
        func(count - 1)

    
func(10)
# Out:
# 10 now
# result:  10
# 9 now
# result:  9
# 8 now
# result:  8
# 7 now
# result:  7
# 6 now
# result:  6
# 5 now
# result:  5
# 4 now
# result:  4
# 3 now
# result:  3
# 2 now
# result:  2
# 1 now
# result:  1
